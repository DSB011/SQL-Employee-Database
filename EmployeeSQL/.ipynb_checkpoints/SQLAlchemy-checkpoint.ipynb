# %%
# Dependencies
# Pandas
import pandas as pd
import psycopg2
import sqlalchemy
import matplotlib.pyplot as plt
import scipy.stats as sts
import numpy as np
# SQL Alchemy
from sqlalchemy import create_engine
from config import Password
engine = create_engine('postgresql://postgres:{Password}@localhost:5432/EmployeeSQL_db')
connection = engine.connect()

# %%
employees_info = pd.read_sql("SELECT * FROM Employees", connection)
salary_info = pd.read_sql("SELECT * FROM Salaries", connection)
title_info = pd.read_sql("SELECT * FROM Titles", connection)

# %%
salary_info
# Out:
#         emp_no  salary
# 0        10001   60117
# 1        10002   65828
# 2        10003   40006
# 3        10004   40054
# 4        10005   78228
# ...        ...     ...
# 300019  499995   40000
# 300020  499996   58058
# 300021  499997   49597
# 300022  499998   40000
# 300023  499999   63707
#
# [300024 rows x 2 columns]

# %%
# Bonus 1 :  histogram to visualize the most common salary ranges for employees
plt.hist(salary_info['salary'], 20, label= "Salary")
plt.axvline(salary_info['salary'].mean(), color='r', linestyle = 'dashed', label="Salary Mean")
plt.xlabel("Salary")
plt.ylabel("Number of Employees")
plt.legend()
plt.title("Common Salary Ranges for Employees")
plt.savefig("Common Salary Ranges for Employees.png")

# %%
title_info
# Out:
#   title_id               title
# 0    s0001               Staff
# 1    s0002        Senior Staff
# 2    e0001  Assistant Engineer
# 3    e0002            Engineer
# 4    e0003     Senior Engineer
# 5    e0004    Technique Leader
# 6    m0001             Manager

# %%
# Bonus 2 :  bar chart of average salary by title.
query_pandas = pd.read_sql("SELECT * FROM (SELECT * FROM Employees INNER JOIN Titles ON Employees.emp_title_id = Titles.title_id) AS joined INNER JOIN Salaries ON joined.emp_no=Salaries.emp_no", connection)

# %%
query_pandas
# Out:
#         emp_no emp_title_id  birth_date first_name    last_name sex  \
# 0        10005        s0001  1955-01-21    Kyoichi     Maliniak   M
# 1        10010        e0002  1963-06-01  Duangkaew     Piveteau   F
# 2        10011        s0001  1953-11-07       Mary        Sluis   F
# 3        10013        s0002  1963-06-07  Eberhardt       Terkki   M
# 4        10017        s0001  1958-07-06  Cristinel    Bouloucos   F
# ...        ...          ...         ...        ...          ...  ..
# 300019  499948        e0002  1953-05-24   Cordelia    Paludetto   M
# 300020  499972        e0003  1957-07-25     Katsuo       Leuchs   F
# 300021  499985        s0001  1964-12-26       Gila  Lukaszewicz   M
# 300022  499987        s0001  1961-09-05      Rimli       Dusink   F
# 300023  499998        s0001  1956-09-05   Patricia      Breugel   M
#
#          hire_date title_id            title  emp_no  salary
# 0       1989-09-12    s0001            Staff   10005   78228
# ...

# %%
avg_salaries_by_title = query_pandas.groupby(["title"]).mean()["salary"]

# Plotting the Bar Chart
titles_col = avg_salaries_by_title.index
avg_salaries_title = avg_salaries_by_title.values

x_axis = np.arange(len(titles_col))
tick_locations = [range for range in x_axis]
plt.xticks(tick_locations,titles_col, rotation=90)
plt.title("Average Salary By Title")
plt.xlabel("Title")
plt.ylabel("Average Salary")
multi_plot = plt.bar(x_axis, avg_salaries_title, color='r', alpha=0.5, align='center')

for i in multi_plot:
    yvalue = i.get_height()
    plt.text(i.get_x(), yvalue + 300, "${:,.2f}K".format(yvalue/1000))
plt.savefig("Average_Salary_Title.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-f5448f6478e7> in <module>
#      16     yvalue = i.get_height()
#      17     plt.text(i.get_x(), yvalue + 300, "${:,.2f}K".format(yvalue/1000))
# ---> 18 plt.savefig("../Images/Average_Salary_Title.png")
#      19 plt.show()
#      20
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     727 def savefig(*args, **kwargs):
#     728     fig = gcf()
# --> 729     res = fig.savefig(*args, **kwargs)
#     730     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     731     return res
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2178             self.patch.set_visible(frameon)
#    2179
# -> 2180         self.canvas.print_figure(fname, **kwargs)
#    2181
# ...
